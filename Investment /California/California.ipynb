# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
# Read the CSV file from the Resources folder into a Pandas DataFrame
population = pd.read_csv("Resources/CAPOP.csv")

population = population.rename(columns={'CAPOP': 'population'})

# Review the DataFrame
population
# Out:
#            DATE  population
# 0    1900-01-01    1490.000
# 1    1901-01-01    1550.000
# 2    1902-01-01    1623.000
# 3    1903-01-01    1702.000
# 4    1904-01-01    1792.000
# ..          ...         ...
# 118  2018-01-01   39437.463
# 119  2019-01-01   39437.610
# 120  2020-01-01   39501.653
# 121  2021-01-01   39142.991
# 122  2022-01-01   39029.342
#
# [123 rows x 2 columns]

# %%
# Convert 'date' column to datetime format
population['DATE'] = pd.to_datetime(population['DATE'])

# Grouping by year extracted from the 'date' column and calculating the sum of 'Value' for each year
population['DATE'] = population['DATE'].dt.year  # Extracting year
population = population.rename(columns={'DATE': 'year'})

# Delete the years to match the other data
population = population.drop(population[population['year'] < 2016].index)

population
# Out:
#      year  population
# 116  2016   39149.186
# 117  2017   39337.785
# 118  2018   39437.463
# 119  2019   39437.610
# 120  2020   39501.653
# 121  2021   39142.991
# 122  2022   39029.342

# %%
# Read the CSV file from the Resources folder into a Pandas DataFrame
employment = pd.read_csv("Resources/CANA.csv")

employment = employment.rename(columns={'CANA': 'employment'})

# Review the DataFrame
employment
# Out:
#           DATE  employment
# 0   2016-01-01     16307.8
# 1   2016-02-01     16349.8
# 2   2016-03-01     16329.3
# 3   2016-04-01     16429.0
# 4   2016-05-01     16452.8
# ..         ...         ...
# 79  2022-08-01     17785.0
# 80  2022-09-01     17806.2
# 81  2022-10-01     17869.6
# 82  2022-11-01     17889.6
# 83  2022-12-01     17869.1
#
# [84 rows x 2 columns]

# %%
# Convert 'date' column to datetime format
employment['DATE'] = pd.to_datetime(employment['DATE'])

# Grouping by year extracted from the 'date' column and calculating the sum of 'Value' for each year
employment['year'] = employment['DATE'].dt.year  # Extracting year
employment = employment.groupby('year')['employment'].mean().reset_index()

employment
# Out:
#    year    employment
# 0  2016  16479.108333
# 1  2017  16827.533333
# 2  2018  17173.341667
# 3  2019  17432.350000
# 4  2020  16185.525000
# 5  2021  16747.983333
# 6  2022  17693.575000

# %%
# Read the CSV file from the Resources folder into a Pandas DataFrame
income = pd.read_csv("Resources/MEHOINUSCAA646N.csv")

income = income.rename(columns={'MEHOINUSCAA646N': 'income'})

# Review the DataFrame
income
# Out:
#          DATE  income
# 0  2016-01-01   66640
# 1  2017-01-01   70040
# 2  2018-01-01   70490
# 3  2019-01-01   78110
# 4  2020-01-01   77650
# 5  2021-01-01   81580
# 6  2022-01-01   85300

# %%
# Convert 'date' column to datetime format
income['DATE'] = pd.to_datetime(income['DATE'])

# Grouping by year extracted from the 'date' column and calculating the sum of 'Value' for each year
income['DATE'] = income['DATE'].dt.year  # Extracting year
income = income.rename(columns={'DATE': 'year'})

# Display the dataframe
income

#(thousand of dollars/year)
# Out:
#    year  income
# 0  2016   66640
# 1  2017   70040
# 2  2018   70490
# 3  2019   78110
# 4  2020   77650
# 5  2021   81580
# 6  2022   85300

# %%
# Read the CSV file from the Resources folder into a Pandas DataFrame
home_size = pd.read_csv("Resources/MEDSQUFEECA.csv")

home_size = home_size.rename(columns={'MEDSQUFEECA': 'home_size(sqft)'})

# Review the DataFrame
home_size
# Out:
#           DATE  home_size(sqft)
# 0   2016-07-01           1900.0
# 1   2016-08-01           1883.0
# 2   2016-09-01           1870.0
# 3   2016-10-01           1863.0
# 4   2016-11-01           1857.0
# ..         ...              ...
# 73  2022-08-01           1749.0
# 74  2022-09-01           1755.0
# 75  2022-10-01           1751.0
# 76  2022-11-01           1750.0
# 77  2022-12-01           1752.0
#
# [78 rows x 2 columns]

# %%
# Convert 'date' column to datetime format
home_size['DATE'] = pd.to_datetime(home_size['DATE'])

# Grouping by year extracted from the 'date' column and calculating the sum of 'Value' for each year
home_size['year'] = home_size['DATE'].dt.year  # Extracting year
home_size = home_size.groupby('year')['home_size(sqft)'].mean().reset_index()

home_size
# Out:
#    year  home_size(sqft)
# 0  2016      1871.833333
# 1  2017      1884.666667
# 2  2018      1858.500000
# 3  2019      1854.916667
# 4  2020      1848.333333
# 5  2021      1762.333333
# 6  2022      1750.500000

# %%
# Read the CSV file from the Resources folder into a Pandas DataFrame
house_prices = pd.read_csv("Resources/CASTHPI.csv")

house_prices = house_prices.rename(columns={'CASTHPI': 'house_prices'})

# Review the DataFrame
house_prices
# Out:
#           DATE  house_prices
# 0   2016-01-01        544.56
# 1   2016-04-01        554.21
# 2   2016-07-01        566.34
# 3   2016-10-01        573.16
# 4   2017-01-01        579.13
# 5   2017-04-01        591.14
# 6   2017-07-01        602.91
# 7   2017-10-01        611.56
# 8   2018-01-01        622.00
# 9   2018-04-01        633.87
# 10  2018-07-01        641.86
# 11  2018-10-01        641.79
# 12  2019-01-01        645.92
# 13  2019-04-01        652.51
# 14  2019-07-01        659.40
# 15  2019-10-01        663.69
# 16  2020-01-01        669.93
# 17  2020-04-01        677.61
# 18  2020-07-01        685.53
# 19  2020-10-01        699.67
# 20  2021-01-01        719.24
# 21  2021-04-01        761.90
# 22  2021-07-01        801.54
# 23  2021-10-01        834.06
# 24  2022-01-01        868.40
# 25  2022-04-01        922.93
# 26  2022-07-01        917.43
# 27  2022-10-01        896.33

# %%
# Convert 'date' column to datetime format
house_prices['DATE'] = pd.to_datetime(house_prices['DATE'])

# Grouping by year extracted from the 'date' column and calculating the sum of 'Value' for each year
house_prices['year'] = house_prices['DATE'].dt.year  # Extracting year
house_prices = house_prices.groupby('year')['house_prices'].mean().reset_index()

house_prices
# Out:
#    year  house_prices
# 0  2016      559.5675
# 1  2017      596.1850
# 2  2018      634.8800
# 3  2019      655.3800
# 4  2020      683.1850
# 5  2021      779.1850
# 6  2022      901.2725

# %%
# Merging population and employment DataFrames on 'year' column
merged_df = pd.merge(population, employment, on='year')

# Merging income DataFrame to the already merged DataFrame
merged_df = pd.merge(merged_df, income, on='year')

# Merging home_size DataFrame to the already merged DataFrame
merged_df = pd.merge(merged_df, home_size, on='year')

# Merging house_prices DataFrame to the already merged DataFrame
merged_df = pd.merge(merged_df, house_prices, on='year')

merged_df
# Out:
#    year  population    employment  income  home_size(sqft)  house_prices
# 0  2016   39149.186  16479.108333   66640      1871.833333      559.5675
# 1  2017   39337.785  16827.533333   70040      1884.666667      596.1850
# 2  2018   39437.463  17173.341667   70490      1858.500000      634.8800
# 3  2019   39437.610  17432.350000   78110      1854.916667      655.3800
# 4  2020   39501.653  16185.525000   77650      1848.333333      683.1850
# 5  2021   39142.991  16747.983333   81580      1762.333333      779.1850
# 6  2022   39029.342  17693.575000   85300      1750.500000      901.2725

# %%
fig, ax1 = plt.subplots(figsize=(10, 6))

# Plotting the first set of values on the primary y-axis (left)
ax1.plot(merged_df['year'], merged_df['population'], marker='o', markersize=4, color='lightcoral', label='population')
ax1.set_xlabel('Year')
ax1.tick_params(axis='y', labelcolor='lightcoral')

# Creating secondary y-axes (right) for other sets of values
ax2 = ax1.twinx()
ax2.plot(merged_df['year'], merged_df['employment'], marker='o', markersize=4, color='orange', label='employment')
ax2.tick_params(axis='y', labelcolor='red')

ax3 = ax1.twinx()
ax3.spines['right'].set_position(('outward', 80))  # Adjust the position of the new axis
ax3.plot(merged_df['year'], merged_df['income'], marker='o', markersize=4, color='yellowgreen', label='income')
ax3.tick_params(axis='y', labelcolor='green')

ax4 = ax1.twinx()
ax4.spines['right'].set_position(('outward', 160))  # Adjust the position of the new axis
ax4.plot(merged_df['year'], merged_df['home_size(sqft)'], marker='o', markersize=4, color='turquoise', label='home size(sqft)')
ax4.tick_params(axis='y', labelcolor='purple')

ax5 = ax1.twinx()
ax5.spines['right'].set_position(('outward', 240))  # Adjust the position of the new axis
ax5.plot(merged_df['year'], merged_df['house_prices'], marker='o', markersize=4, color='slateblue', label='house prices')
ax5.tick_params(axis='y', labelcolor='orange')

# Adding legends
lines1, labels1 = ax1.get_legend_handles_labels()
lines2, labels2 = ax2.get_legend_handles_labels()
lines3, labels3 = ax3.get_legend_handles_labels()
lines4, labels4 = ax4.get_legend_handles_labels()
lines5, labels5 = ax5.get_legend_handles_labels()

plt.title('California')
plt.show()
