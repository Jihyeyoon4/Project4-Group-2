# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
# Read the CSV file from the Resources folder into a Pandas DataFrame
population = pd.read_csv("Resources/AZPOP.csv")

population = population.rename(columns={'AZPOP': 'population'})

# Review the DataFrame
population
# Out:
#          DATE  population
# 0  2016-01-01    6944.767
# 1  2017-01-01    7048.088
# 2  2018-01-01    7164.228
# 3  2019-01-01    7291.843
# 4  2020-01-01    7179.943
# 5  2021-01-01    7264.877
# 6  2022-01-01    7359.197

# %%
# Convert 'date' column to datetime format
population['DATE'] = pd.to_datetime(population['DATE'])

# Grouping by year extracted from the 'date' column and calculating the sum of 'Value' for each year
population['DATE'] = population['DATE'].dt.year  # Extracting year
population = population.rename(columns={'DATE': 'year'})

# Delete the years to match the other data
population = population.drop(population[population['year'] < 2016].index)

population
# Out:
#    year  population
# 0  2016    6944.767
# 1  2017    7048.088
# 2  2018    7164.228
# 3  2019    7291.843
# 4  2020    7179.943
# 5  2021    7264.877
# 6  2022    7359.197

# %%
# Read the CSV file from the Resources folder into a Pandas DataFrame
employment = pd.read_csv("Resources/AZNA.csv")

employment = employment.rename(columns={'AZNA': 'employment'})

# Review the DataFrame
employment
# Out:
#           DATE  employment
# 0   2016-01-01      2672.4
# 1   2016-02-01      2682.1
# 2   2016-03-01      2687.9
# 3   2016-04-01      2696.3
# 4   2016-05-01      2701.8
# ..         ...         ...
# 79  2022-08-01      3106.3
# 80  2022-09-01      3113.0
# 81  2022-10-01      3113.0
# 82  2022-11-01      3123.9
# 83  2022-12-01      3122.6
#
# [84 rows x 2 columns]

# %%
# Convert 'date' column to datetime format
employment['DATE'] = pd.to_datetime(employment['DATE'])

# Grouping by year extracted from the 'date' column and calculating the sum of 'Value' for each year
employment['year'] = employment['DATE'].dt.year  # Extracting year
employment = employment.groupby('year')['employment'].mean().reset_index()

employment
# Out:
#    year   employment
# 0  2016  2708.816667
# 1  2017  2777.408333
# 2  2018  2858.058333
# 3  2019  2942.633333
# 4  2020  2853.575000
# 5  2021  2970.325000
# 6  2022  3095.741667

# %%
# Read the CSV file from the Resources folder into a Pandas DataFrame
income = pd.read_csv("Resources/MEHOINUSAZA672N.csv")

income = income.rename(columns={'MEHOINUSAZA672N': 'income'})

# Review the DataFrame
income
# Out:
#          DATE  income
# 0  2016-01-01   68510
# 1  2017-01-01   70390
# 2  2018-01-01   71990
# 3  2019-01-01   80500
# 4  2020-01-01   75620
# 5  2021-01-01   76370
# 6  2022-01-01   73450

# %%
# Convert 'date' column to datetime format
income['DATE'] = pd.to_datetime(income['DATE'])

# Grouping by year extracted from the 'date' column and calculating the sum of 'Value' for each year
income['DATE'] = income['DATE'].dt.year  # Extracting year
income = income.rename(columns={'DATE': 'year'})

# Display the dataframe
income

#(thousand of dollars/year)
# Out:
#    year  income
# 0  2016   68510
# 1  2017   70390
# 2  2018   71990
# 3  2019   80500
# 4  2020   75620
# 5  2021   76370
# 6  2022   73450

# %%
# Read the CSV file from the Resources folder into a Pandas DataFrame
home_size = pd.read_csv("Resources/MEDSQUFEEAZ.csv")

home_size = home_size.rename(columns={'MEDSQUFEEAZ': 'home_size(sqft)'})

# Review the DataFrame
home_size
# Out:
#           DATE  home_size(sqft)
# 0   2016-07-01           2089.0
# 1   2016-08-01           2072.0
# 2   2016-09-01           2073.0
# 3   2016-10-01           2070.0
# 4   2016-11-01           2052.0
# ..         ...              ...
# 73  2022-08-01           1888.0
# 74  2022-09-01           1874.0
# 75  2022-10-01           1879.0
# 76  2022-11-01           1878.0
# 77  2022-12-01           1862.0
#
# [78 rows x 2 columns]

# %%
# Convert 'date' column to datetime format
home_size['DATE'] = pd.to_datetime(home_size['DATE'])

# Grouping by year extracted from the 'date' column and calculating the sum of 'Value' for each year
home_size['year'] = home_size['DATE'].dt.year  # Extracting year
home_size = home_size.groupby('year')['home_size(sqft)'].mean().reset_index()

home_size
# Out:
#    year  home_size(sqft)
# 0  2016      2065.666667
# 1  2017      2086.166667
# 2  2018      2087.166667
# 3  2019      2099.250000
# 4  2020      2054.666667
# 5  2021      1945.916667
# 6  2022      1902.750000

# %%
# Read the CSV file from the Resources folder into a Pandas DataFrame
house_prices = pd.read_csv("Resources/AZSTHPI.csv")

house_prices = house_prices.rename(columns={'AZSTHPI': 'house_prices'})

# Review the DataFrame
house_prices
# Out:
#           DATE  house_prices
# 0   2016-01-01        333.00
# 1   2016-04-01        339.93
# 2   2016-07-01        345.58
# 3   2016-10-01        351.18
# 4   2017-01-01        356.33
# 5   2017-04-01        365.53
# 6   2017-07-01        373.24
# 7   2017-10-01        377.61
# 8   2018-01-01        385.45
# 9   2018-04-01        393.53
# 10  2018-07-01        402.62
# 11  2018-10-01        407.27
# 12  2019-01-01        412.54
# 13  2019-04-01        420.72
# 14  2019-07-01        427.05
# 15  2019-10-01        434.40
# 16  2020-01-01        443.13
# 17  2020-04-01        450.87
# 18  2020-07-01        461.88
# 19  2020-10-01        478.18
# 20  2021-01-01        499.51
# 21  2021-04-01        539.26
# 22  2021-07-01        584.01
# 23  2021-10-01        613.79
# 24  2022-01-01        643.06
# 25  2022-04-01        693.14
# 26  2022-07-01        702.91
# 27  2022-10-01        680.08

# %%
# Convert 'date' column to datetime format
house_prices['DATE'] = pd.to_datetime(house_prices['DATE'])

# Grouping by year extracted from the 'date' column and calculating the sum of 'Value' for each year
house_prices['year'] = house_prices['DATE'].dt.year  # Extracting year
house_prices = house_prices.groupby('year')['house_prices'].mean().reset_index()

house_prices
# Out:
#    year  house_prices
# 0  2016      342.4225
# 1  2017      368.1775
# 2  2018      397.2175
# 3  2019      423.6775
# 4  2020      458.5150
# 5  2021      559.1425
# 6  2022      679.7975

# %%
# Merging population and employment DataFrames on 'year' column
merged_df = pd.merge(population, employment, on='year')

# Merging income DataFrame to the already merged DataFrame
merged_df = pd.merge(merged_df, income, on='year')

# Merging home_size DataFrame to the already merged DataFrame
merged_df = pd.merge(merged_df, home_size, on='year')

# Merging house_prices DataFrame to the already merged DataFrame
merged_df = pd.merge(merged_df, house_prices, on='year')

merged_df
# Out:
#    year  population   employment  income  home_size(sqft)  house_prices
# 0  2016    6944.767  2708.816667   68510      2065.666667      342.4225
# 1  2017    7048.088  2777.408333   70390      2086.166667      368.1775
# 2  2018    7164.228  2858.058333   71990      2087.166667      397.2175
# 3  2019    7291.843  2942.633333   80500      2099.250000      423.6775
# 4  2020    7179.943  2853.575000   75620      2054.666667      458.5150
# 5  2021    7264.877  2970.325000   76370      1945.916667      559.1425
# 6  2022    7359.197  3095.741667   73450      1902.750000      679.7975

# %%
fig, ax1 = plt.subplots(figsize=(10, 6))

# Plotting the first set of values on the primary y-axis (left)
ax1.plot(merged_df['year'], merged_df['population'], marker='o', markersize=4, color='lightcoral', label='population')
ax1.set_xlabel('Year')
ax1.tick_params(axis='y', labelcolor='lightcoral')

# Creating secondary y-axes (right) for other sets of values
ax2 = ax1.twinx()
ax2.plot(merged_df['year'], merged_df['employment'], marker='o', markersize=4, color='orange', label='employment')
ax2.tick_params(axis='y', labelcolor='red')

ax3 = ax1.twinx()
ax3.spines['right'].set_position(('outward', 80))  # Adjust the position of the new axis
ax3.plot(merged_df['year'], merged_df['income'], marker='o', markersize=4, color='yellowgreen', label='income')
ax3.tick_params(axis='y', labelcolor='green')

ax4 = ax1.twinx()
ax4.spines['right'].set_position(('outward', 160))  # Adjust the position of the new axis
ax4.plot(merged_df['year'], merged_df['home_size(sqft)'], marker='o', markersize=4, color='turquoise', label='home size(sqft)')
ax4.tick_params(axis='y', labelcolor='purple')

ax5 = ax1.twinx()
ax5.spines['right'].set_position(('outward', 240))  # Adjust the position of the new axis
ax5.plot(merged_df['year'], merged_df['house_prices'], marker='o', markersize=4, color='slateblue', label='house prices')
ax5.tick_params(axis='y', labelcolor='orange')

# Adding legends
lines1, labels1 = ax1.get_legend_handles_labels()
lines2, labels2 = ax2.get_legend_handles_labels()
lines3, labels3 = ax3.get_legend_handles_labels()
lines4, labels4 = ax4.get_legend_handles_labels()
lines5, labels5 = ax5.get_legend_handles_labels()

plt.title('Arizona')
plt.show()
